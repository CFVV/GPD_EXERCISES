# %% [markdown]
# ## EJERCICIO 1: URBAN DEVELOPMENT CHILE

# %%
# librerias clasicas
import numpy as np
import pandas as pd

import warnings
warnings.filterwarnings("ignore")

#libreria sklearn
#from sklearn.cluster import DBSCAN 
from sklearn.preprocessing import StandardScaler 
from sklearn.preprocessing import normalize 
from sklearn.decomposition import PCA 

# librerias para graficar
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
plt.style.use('seaborn-whitegrid')
plt.rcParams['figure.figsize']=(12, 10)

# %%
#carga dataset y exclusion de columnas
df_ud= pd.read_csv("urban-development_chl.csv")#.drop(['id','Unnamed: 32'],axis=1)
df_ud.head(20)
# Out:
#      Country Name   Country ISO3        Year  \
# 0   #country+name  #country+code  #date+year
# 1           Chile            CHL        2010
# 2           Chile            CHL        2000
# 3           Chile            CHL        1990
# 4           Chile            CHL        2010
# 5           Chile            CHL        2000
# 6           Chile            CHL        1990
# 7           Chile            CHL        2010
# 8           Chile            CHL        2000
# 9           Chile            CHL        1990
# 10          Chile            CHL        2017
# 11          Chile            CHL        2016
# 12          Chile            CHL        2015
# 13          Chile            CHL        2014
# 14          Chile            CHL        2013
# 15          Chile            CHL        2012
# 16          Chile            CHL        2011
# 17          Chile            CHL        2010
# 18          Chile            CHL        2009
# 19          Chile            CHL        2008
#
# ...

# %%
df_ud.shape
# Out:
# (563, 6)

# %%
df_ud.describe()
# Out:
#        Country Name Country ISO3  Year  \
# count           563          563   563
# unique            2            2    60
# top           Chile          CHL  2000
# freq            562          562    17
#
#                                            Indicator Name Indicator Code Value
# count                                                 563            563   563
# unique                                                 20             20   492
# top     Population in urban agglomerations of more tha...    SP.URB.TOTL   100
# freq                                                   59             59     4

# %%
df_ud.columns
# Out:
# Index(['Country Name', 'Country ISO3', 'Year', 'Indicator Name',
#        'Indicator Code', 'Value'],
#       dtype='object')

# %%
df_ud['Indicator Name'].unique()
# Out:
# array(['#indicator+name',
#        'Urban land area where elevation is below 5 meters (sq. km)',
#        'Urban land area where elevation is below 5 meters (% of total land area)',
#        'Urban land area (sq. km)',
#        'Access to electricity, urban (% of urban population)',
#        'PM2.5 air pollution, mean annual exposure (micrograms per cubic meter)',
#        'PM2.5 air pollution, population exposed to levels exceeding WHO guideline value (% of total)',
#        'Population density (people per sq. km of land area)',
#        'Urban population living in areas where elevation is below 5 meters (% of total population)',
#        'Population living in slums (% of urban population)',
#        'Population in largest city',
#        'Population in the largest city (% of urban population)',
#        'Population in urban agglomerations of more than 1 million',
#        'Population in urban agglomerations of more than 1 million (% of total population)',
# ...

# %%
df_in= pd.read_csv("infrastructure_chl.csv")
df_in.head(20)
# Out:
#      Country Name   Country ISO3        Year  \
# 0   #country+name  #country+code  #date+year
# 1           Chile            CHL        2017
# 2           Chile            CHL        2016
# 3           Chile            CHL        2015
# 4           Chile            CHL        2014
# 5           Chile            CHL        2013
# 6           Chile            CHL        2012
# 7           Chile            CHL        2011
# 8           Chile            CHL        2010
# 9           Chile            CHL        2009
# 10          Chile            CHL        2008
# 11          Chile            CHL        2007
# 12          Chile            CHL        2006
# 13          Chile            CHL        2005
# 14          Chile            CHL        2004
# 15          Chile            CHL        2003
# 16          Chile            CHL        2002
# 17          Chile            CHL        2001
# 18          Chile            CHL        2000
# 19          Chile            CHL        1999
#
# ...
